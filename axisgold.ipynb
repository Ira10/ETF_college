# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

data1 = pd.read_excel("/content/goog AXISGOLD jan,2015 - 10 nov,2016.xlsx")
data2 = pd.read_excel("/content/goog AXISGOLD 11 nov,2016 - 31 march,20.xlsx")
data3 = pd.read_excel("/content/goog AXISGOLD 1 april,2020 - 31 march,2022.xlsx")
data1.head(2)
# Out:
#                   Date  Close
# 0  2015-02-01 15:30:00  25.00
# 1  2015-09-01 15:30:00  25.14

# %%
data2.head()
# Out:
#                   Date  Close
# 0  18/11/2016 15:30:00  27.18
# 1  25/11/2016 15:30:00  26.45
# 2  2016-02-12 15:30:00  26.04
# 3  2016-09-12 15:30:00  25.65
# 4  16/12/2016 15:30:00  24.94

# %%
data3.head(2)
# Out:
#                   Date  Close
# 0  2020-03-04 15:30:00  38.76
# 1  2020-09-04 15:30:00  40.49

# %%
data1.plot('Date','Close',figsize=(20, 10))
plt.show()

# %%
data2.plot('Date','Close',figsize=(20, 10))
plt.show()

# %%
data3.plot('Date','Close',figsize=(20, 10))
plt.show()
