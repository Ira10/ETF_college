# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

data1 = pd.read_excel("/content/goog GOLDBEES Jan,2015 - 10 Nov,2016.xlsx")
data2 = pd.read_excel("/content/goog GOLDBEES 11 Nov,2016 - 31 March,2020.xlsx")
data3 = pd.read_excel("/content/goog GOLDBEES 1 april,2020 - 31 march,2022.xlsx")
data1.head(2)
# Out:
#                   Date  Close
# 0  16/01/2015 15:30:00  25.32
# 1  23/01/2015 15:30:00  25.77

# %%
data3.head(2)
# Out:
#                   Date  Close
# 0  2020-03-04 15:30:00  38.79
# 1  2020-09-04 15:30:00  40.79

# %%
data2.head(2)
# Out:
#                   Date  Close
# 0  2016-11-11 15:30:00  27.54
# 1  18/11/2016 15:30:00  26.48

# %%
data1.plot('Date','Close',figsize=(20, 10))
plt.show()

# %%
data2.plot('Date','Close',figsize=(20, 10))
plt.show()

# %%
data3.plot('Date','Close',figsize=(20, 10))
plt.show()

# %%
display(data1,data2,data3)
# Out:
#                    Date  Close
# 0   16/01/2015 15:30:00  25.32
# 1   23/01/2015 15:30:00  25.77
# 2   30/01/2015 15:30:00  25.79
# 3   2015-06-02 15:30:00  25.50
# 4   13/02/2015 15:30:00  24.99
# ..                  ...    ...
# 89  2016-07-10 15:30:00  27.62
# 90  14/10/2016 15:30:00  27.49
# 91  21/10/2016 15:30:00  27.45
# 92  28/10/2016 15:30:00  27.39
# 93  2016-04-11 15:30:00  27.72
#
# [94 rows x 2 columns]
#                     Date  Close
# 0    2016-11-11 15:30:00  27.54
# 1    18/11/2016 15:30:00  26.48
# 2    25/11/2016 15:30:00  26.34
# 3    2016-02-12 15:30:00  25.94
# 4    2016-09-12 15:30:00  25.73
# ..                   ...    ...
# 172  28/02/2020 15:30:00  37.37
# 173  2020-06-03 15:30:00  39.05
# 174  13/03/2020 15:30:00  36.62
# 175  20/03/2020 15:30:00  36.11
# 176  27/03/2020 15:30:00  38.17
#
# [177 rows x 2 columns]
#                     Date  Close
# 0    2020-03-04 15:30:00  38.79
# 1    2020-09-04 15:30:00  40.79
# 2    17/04/2020 15:30:00  42.47
# ...

# %%
data4 = pd.merge(data1, data2)
data4.head(5)
# Out:
# Empty DataFrame
# Columns: [Date, Close]
# Index: []

# %%
files = pd.read_excel("/content/goog GOLDBEES Jan,2015 - 10 Nov,2016.xlsx","/content/goog GOLDBEES 11 Nov,2016 - 31 March,2020.xlsx","/content/goog GOLDBEES 1 april,2020 - 31 march,2022.xlsx")
df = pd.DataFrame()
for file in files:
     if file.endswith('.xlsx'):
         df = df.append(pd.read_excel(file), ignore_index=True) 
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Starting with pandas version 2.0 all arguments of read_excel except for the arguments 'io' and 'sheet_name' will be keyword-only
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8f3e74f883be> in <module>()
# ----> 1 files = pd.read_excel("/content/goog GOLDBEES Jan,2015 - 10 Nov,2016.xlsx","/content/goog GOLDBEES 11 Nov,2016 - 31 March,2020.xlsx","/content/goog GOLDBEES 1 april,2020 - 31 march,2022.xlsx")
#       2 df = pd.DataFrame()
#       3 for file in files:
#       4      if file.endswith('.xlsx'):
#       5          df = df.append(pd.read_excel(file), ignore_index=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
# ...
