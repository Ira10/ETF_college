# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
data = pd.read_excel("/content/goldbees, icici_gold, axis_gold.xlsx")
data.head(2)
data.describe()
# Out:
#        AXISGOLD_Close  GOLDBEES_Close  ICICGOLD_Close
# count      372.000000      372.000000      372.000000
# mean        31.459543       31.546478       32.288172
# std          7.236349        7.181159        7.361417
# min         22.440000       22.610000       23.340000
# 25%         25.940000       26.270000       26.797500
# 50%         27.920000       27.890000       28.550000
# 75%         40.185000       40.202500       41.190000
# max         52.350000       49.170000       50.190000

# %%
data['AXISGOLD_Close'].plot()
data['GOLDBEES_Close'].plot()
data['ICICGOLD_Close'].plot()
plt.show()

# %%
data['AXISGOLD_Close'].plot()
plt.show()
data['GOLDBEES_Close'].plot()
plt.show()
data['ICICGOLD_Close'].plot()
plt.show()

# %%
data['AXISGOLD_Close'].plot()
plt.ylabel('Date', fontsize=14)
plt.show()

# %%
#Plot all the close prices
data.plot('Date', figsize=(20, 10))

#Show the legend
plt.legend()

#Define the label for the title of the figure
plt.title("Close Price", fontsize=16)

#Define the labels for x-axis and y-axis
plt.ylabel('Date', fontsize=14)

#Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5) 
plt.show()

# %% [markdown]
# # Plot all the close prices
# data.plot('Date', figsize=(20, 10))
#
# # Show the legend
# plt.legend()
#
# # Define the label for the title of the figure
# plt.title("Close Price", fontsize=16)
#
# # Define the labels for x-axis and y-axis
# plt.ylabel('Date', fontsize=14)
#
# # Plot the grid lines
# plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
# plt.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(x=data.Date,y=data['AXISGOLD_Close'], mode='lines'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(x=data.Date,y=data['ICICGOLD_Close'], mode='lines'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(x=data.Date,y=data['GOLDBEES_Close'], mode='lines'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# import pandas as pd
# from matplotlib import pyplot as plt
#
# # Read CSV into pandas
# df = pd.DataFrame(data)
#
# # Figure Size
# fig = plt.figure(figsize =(10, 7))
#
# # Horizontal Bar Plot
# plt.bar( AXISGOLD_Close, ICICGOLD_Close, color ='maroon',
#         width = 0.4)
#
# # Show Plot
# plt.show()

# %%
data.head(1)

# %%
data.tail(1)

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["AXISGOLD_Close", "GOLDBEES_Close","ICICGOLD_Close"]
df = pd.read_excel("/content/goldbees, icici_gold, axis_gold.xlsx", usecols=columns)
plt.plot(df.AXISGOLD_Close, df.GOLDBEES_Close,df.ICICGOLD_Close)
plt.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(x=data.Date,y=data['AXISGOLD_Close'], mode='lines'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
