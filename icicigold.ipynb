# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

data1 = pd.read_excel("/content/goog ICICIGOLD jan,2015 - 10 nov,2016.xlsx")
data2 = pd.read_excel("/content/goog ICICIGOLD 11novt,2016 - 31march,2020.xlsx")
data3 = pd.read_excel("/content/goog ICICIGOLD 1april,2020 - 31 march,2022.xlsx")
data1.head(2)
# Out:
#                   Date  Close
# 0  2015-02-01 15:30:00  25.25
# 1  2015-09-01 15:30:00  25.26

# %%
data2.head()
# Out:
#                   Date  Close
# 0  18/11/2016 15:30:00  27.09
# 1  25/11/2016 15:30:00  26.93
# 2  2016-02-12 15:30:00  26.38
# 3  2016-09-12 15:30:00  26.03
# 4  16/12/2016 15:30:00  25.46

# %%
data3.head(2)
# Out:
#                   Date  Close
# 0  2020-03-04 15:30:00  40.66
# 1  2020-09-04 15:30:00  42.46

# %%
data1.plot('Date','Close',figsize=(20, 10))
plt.show()

# %%
data2.plot('Date','Close',figsize=(20, 10))
plt.show()

# %%
data3.plot('Date','Close',figsize=(20, 10))
plt.show()
